# %% [markdown]
# <a href="https://colab.research.google.com/github/RutujaBidkar/Certifications/blob/main/Numpy_DataType.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import numpy as np
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

np.concatenate((a, b))
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
np.vstack((a, b))
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.hstack((a, b))
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
np.stack((a, b))
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr = np.arange(1, 10)

np.split(arr, 3)
# Out:
# [array([1, 2, 3]), array([4, 5, 6]), array([7, 8, 9])]

# %%
np.hsplit(arr,3)
# Out:
# [array([1, 2, 3]), array([4, 5, 6]), array([7, 8, 9])]

# %%
a = np.array([[1, 2, 3],
              [4, 5, 6]])

b = np.array([10, 20, 30])

a + b
# Out:
# array([[11, 22, 33],
#        [14, 25, 36]])

# %%
arr = np.array([40, 10, 30, 20])

np.sort(arr)
# Out:
# array([10, 20, 30, 40])

# %%
np.argsort(arr)
# Out:
# array([1, 3, 2, 0])

# %%
np.argmax(arr)
# Out:
# np.int64(0)

# %%
np.argmin(arr)
# Out:
# np.int64(1)

# %%
arr = np.array([10, 20, np.nan, 40])
np.isnan(arr)
# Out:
# array([False, False,  True, False])

# %%
np.mean(arr)
# Out:
# np.float64(nan)

# %%
arr = np.array([10, 20, 20, 30, 30, 30])
np.unique(arr)
# Out:
# array([10, 20, 30])

# %%
np.unique(arr, return_counts=True)
# Out:
# (array([10, 20, 30]), array([1, 2, 3]))
